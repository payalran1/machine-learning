# %% [markdown]
# <h1>Lesson 5. Model selection: US Salary Prediction</h1>

# %% [markdown]
# <img src=https://upload.wikimedia.org/wikipedia/commons/thumb/9/93/White_House_lawn_%281%29.tif/lossy-page1-2433px-White_House_lawn_%281%29.tif.jpg style="height:300px;">
#
# <p>In this exercise you will use the US Adult Census data relating income to social factors such as Age, Education, race etc...</p>
#
# <p>The goal here is to train a binary classifier on the training dataset to predict the column income_bracket which has two possible values ">50K" and "<=50K" and evaluate the accuracy of the classifier with the test dataset.</p>

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing, metrics
from sklearn.model_selection import train_test_split


train=pd.read_csv('census-training.csv')
print(train.info())
train.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 10 columns):
# Age              48842 non-null int64
# EducationNum     48842 non-null int64
# MaritalStatus    48842 non-null object
# Occupation       48842 non-null object
# Relationship     48842 non-null object
# Race             48842 non-null object
# Gender           48842 non-null object
# Hours/Week       48842 non-null int64
# Country          48842 non-null object
# Income           48842 non-null object
# dtypes: int64(3), object(7)
# memory usage: 3.7+ MB
# None
#     Age  EducationNum       MaritalStatus         Occupation   Relationship  \
# 0    25             7       Never-married  Machine-op-inspct      Own-child
# 1    38             9  Married-civ-spouse    Farming-fishing        Husband
# 2    28            12  Married-civ-spouse    Protective-serv        Husband
# 3    44            10  Married-civ-spouse  Machine-op-inspct        Husband
# ...

# %% [markdown]
# <h3>Q.1. Write a command that will calculate the number of unique values for each feature in the training data.</h3>

# %%
print('count of unique values for Age is ', train.Age.unique().size)
print('count of unique values for EducationNum is ', train.EducationNum.unique().size)
print('count of unique values for MaritalStatus is ', train.MaritalStatus.unique().size)
print('count of unique values for Occupation is ', train.Occupation.unique().size)
print('count of unique values for Relationship is ', train.Relationship.unique().size)
print('count of unique values for Race is ', train.Race.unique().size)
print('count of unique values for Gender is ', train.Gender.unique().size)
print('count of unique values for Hours/Week is ', train['Hours/Week'].unique().size)
print('count of unique values for Country is ', train.Country.unique().size)
# Out:
# count of unique values for Age is  74
# count of unique values for EducationNum is  16
# count of unique values for MaritalStatus is  7
# count of unique values for Occupation is  15
# count of unique values for Relationship is  6
# count of unique values for Race is  5
# count of unique values for Gender is  2
# count of unique values for Hours/Week is  96
# count of unique values for Country is  42

# %% [markdown]
# <h3>Q.2. There is a special character '?' inserted in the data in place of null values.  Write a command that will remove it and replace with NaN.</h3>

# %%
# Command (s): remove the '?' special character and replace with NaN
import numpy as np
train.replace('?',np.nan, inplace=True)

train.isnull().sum() #checking the dataset for NaN values .... NaN values in two columns
# Out:
# Age                 0
# EducationNum        0
# MaritalStatus       0
# Occupation       2809
# Relationship        0
# Race                0
# Gender              0
# Hours/Week          0
# Country           857
# Income              0
# dtype: int64

# %% [markdown]
# <h3>Q.3. Replace all missing values in Occupation and Country by their mode (most occuring values). </h3>

# %%
#Command(s):
train.mode() # finding mode to compute the most occuring item in every column
#replace missing values with their mode
train['Occupation'].fillna(train['Occupation'].mode()[0], inplace=True)
train['Country'].fillna(train['Country'].mode()[0], inplace=True)

train.isnull().sum() #checking the data for NaN values .... should all show 0 now
# Out:
# Age              0
# EducationNum     0
# MaritalStatus    0
# Occupation       0
# Relationship     0
# Race             0
# Gender           0
# Hours/Week       0
# Country          0
# Income           0
# dtype: int64

# %% [markdown]
# <h3>Q.4. Write functions to replace Gender and Income attributes to "0" and "1". </h3>

# %%
# converting Gender to "0" and "1" 
def gender_to_numeric(x):
    #TODO return 1 if gender is Male, 0 otherwise  
    if str(x) == 'Male':
        return 1
    else:
        return 0
    
train['Gender'] = train.apply(lambda x:gender_to_numeric(x['Gender']),axis=1)#TODO apply the function to this column

# converting Inccome to "0" and "1" 
def income_to_numeric(x):
    #TODO return 1 if income is greater than 50k, 0 otherwise
    if str(x) == '>50K.':
        return 1
    else:
        return 0
    
train['Income'] = train.apply(lambda x:income_to_numeric(x['Income']),axis=1)#TODO apply the function to this column

train.head(10)
# Out:
#    Age  EducationNum       MaritalStatus         Occupation   Relationship  \
# 0   25             7       Never-married  Machine-op-inspct      Own-child
# 1   38             9  Married-civ-spouse    Farming-fishing        Husband
# 2   28            12  Married-civ-spouse    Protective-serv        Husband
# 3   44            10  Married-civ-spouse  Machine-op-inspct        Husband
# 4   18            10       Never-married     Prof-specialty      Own-child
# 5   34             6       Never-married      Other-service  Not-in-family
# 6   29             9       Never-married     Prof-specialty      Unmarried
# 7   63            15  Married-civ-spouse     Prof-specialty        Husband
# 8   24            10       Never-married      Other-service      Unmarried
# 9   55             4  Married-civ-spouse       Craft-repair        Husband
#
#     Race  Gender  Hours/Week        Country  Income
# 0  Black       1          40  United-States       0
# ...

# %% [markdown]
# <h3>Q.5. Use the label encoder API to encode all object-type in the data. </h3>

# %%
from sklearn import preprocessing
# Command(s) 
obj = train.select_dtypes(include=['object']) #all features that are 'object' datatypes
le = preprocessing.LabelEncoder()

#obj.head()

for i in range(len(obj.columns)):
    train[obj.columns[i]] = le.fit_transform(train[obj.columns[i]])#TODO  #Encode input data
    
train.head(10) #Inspect the data, all features should be numeric now
# Out:
#    Age  EducationNum  MaritalStatus  Occupation  Relationship  Race  Gender  \
# 0   25             7              4           6             3     2       1
# 1   38             9              2           4             0     4       1
# 2   28            12              2          10             0     4       1
# 3   44            10              2           6             0     2       1
# 4   18            10              4           9             3     4       0
# 5   34             6              4           7             1     4       1
# 6   29             9              4           9             4     2       1
# 7   63            15              2           9             0     4       1
# 8   24            10              4           7             4     4       0
# 9   55             4              2           2             0     4       1
#
#    Hours/Week  Country  Income
# 0          40       38       0
# 1          50       38       0
# 2          40       38       1
# ...

# %% [markdown]
# <h3>Q.6. Split the data into 70% training and 30% test </h3>

# %%
from sklearn.model_selection import train_test_split

X = train.drop('Income', axis=1)
y = train[['Income']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %% [markdown]
# <h3>Q.7. Train the logistic regression model on the train dataset and evaluate its performance on the test dataset.</p>

# %%
#Initialize classifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score
from sklearn.metrics import roc_auc_score

log_rgr = LogisticRegression()#TODO Initialize logistic regression classifier
model = log_rgr.fit(X, y.values.ravel())# TODO: fit X_train and y_train

#predict on the test set
y_pred = log_rgr.predict(X_test)#TODO 
lr_acc = log_rgr.score(X_test, y_test)#TODO: Compute the accuracy score
# calculate the fpr and tpr for all thresholds of the classification
probs = log_rgr.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = roc_auc_score(y_test, log_rgr.predict(X_test))#TODO
print("Accuracy: {}".format(lr_acc))
print("AUC: {}".format(roc_auc))

# Plot the ROC curve
import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Accuracy: 0.9197433972565345
# AUC: 0.5002778895069833

# %% [markdown]
# <h3>Q.8. Train the KNN classifier (with k=15) on the train dataset and evaluate its performance on the test dataset. Compare your results with the one above</p>

# %%
from sklearn.neighbors import KNeighborsClassifier

#Initialize the classifier
knn = KNeighborsClassifier(n_neighbors=15)#TODO Initialize KNN classifier with k=15
knn.fit(X, y.values.ravel()) # TODO: fit X_train and y_train

y_pred = knn.predict(X_test)#TODO 
knn_acc = knn.score(X_test, y_test)#TODO: Compute the accuracy score
# calculate the fpr and tpr for all thresholds of the classification
probs = knn.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = roc_auc_score(y_test, knn.predict(X_test))#TODO
print("Accuracy: {}".format(knn_acc))
print("AUC: {}".format(roc_auc))

# Plot the ROC curve
import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

#Compare results
#TODO
#[payal] knn performs little bit better as it has better accuracy and AUC.
# Accuracy is 1% better: Accuracy of logistic regression is 91.97% while for knn its 92.08 %
# AUC is better by 0.1: AUC for logistic regression is 0.50 while for knn its 0.51
# Out:
# Accuracy: 0.9208353238244728
# AUC: 0.5098221671586968

# %% [markdown]
# <h3>Q.9. Perform recursive feature elimination (5 features) on the dataset using the logistic regression classifier. Any difference in the results? Explain.</h3>

# %%
from sklearn.feature_selection import RFE
from sklearn.svm import SVR

X = train.drop('Income', axis=1)
y = train[['Income']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)
estimator = SVR(kernel="linear")
rfe = RFE(estimator, 5, step=1) #TODO
rfe = rfe.fit(X_train,y_train.values.ravel())# TODO: fit X_train and y_train

y_pred = rfe.predict(X_test)# TODO
lr_acc = rfe.score(X_test, y_test)#TODO: Compute the accuracy score

# calculate the fpr and tpr for all thresholds of the classification
probs = rfe.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc =roc_auc_score(y_test, rfe.predict(X_test))#TODO

print("Accuracy: {}".format(lr_acc))
print("AUC: {}".format(roc_auc))

#[payal] not significant change in results

# %%
#what was your incoming experience with this model, if any?
#[payal] transforming data from object to int was new to me and very useful since I deal with data containing strings
#what steps you took, what obstacles you encountered.
#[payal] referred to documentation available for these functions and was able to perform most of the steps easily
#how you link this exercise to real-world, machine learning problem-solving. (What steps were missing? What else do you need to learn?)
#[payal] if the number of unique strings are large, then it will result in many features, I need to learn different ways of dealing with such data
